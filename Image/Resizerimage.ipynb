# %%
# Install Pillow library 
# !pip install pillow

# %%
import os
from PIL import Image
import shutil

# %%
print(os.getcwd())
# Out:
# C:\Users\SMART

# %%
os.makedirs("images_input", exist_ok=True)

print("✅ Folder 'images_input' created.")
# Out:
# ✅ Folder 'images_input' created.

# %%
print("Files in images_input:", os.listdir("images_input"))
# Out:
# Files in images_input: ['car3.png', 'car4.png', 'hero.jpg', 'mission.jpg']

# %%
def resize_images(input_folder, output_folder, size=(300, 300)):
    """
    Resize and convert all images in a folder.
    """
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
            img_path = os.path.join(input_folder, filename)
            img = Image.open(img_path)

            img_resized = img.resize(size)

           
            if img_resized.mode == "RGBA":
                img_resized = img_resized.convert("RGB")

        
            save_path = os.path.join(output_folder, os.path.splitext(filename)[0] + ".jpg")
            img_resized.save(save_path, "JPEG")
            
           
            print(f"✅ Resized and saved: {save_path}")

# %%
input_folder = "images_input"    
output_folder = "images_output"  

resize_images(input_folder, output_folder, size=(400, 400))
# Out:
# ✅ Resized and saved: images_output\car3.jpg
# ✅ Resized and saved: images_output\car4.jpg
# ✅ Resized and saved: images_output\hero.jpg
# ✅ Resized and saved: images_output\mission.jpg

# %%
print("Files in output folder:", os.listdir("images_output"))
# Out:
# Files in output folder: ['car3.jpg', 'car4.jpg', 'hero.jpg', 'mission.jpg']

# %%
from PIL import Image
import matplotlib.pyplot as plt

imgs = ["hero.jpg", "car3.jpg", "car4.jpg", "mission.jpg"]

plt.figure(figsize=(10, 8))

for i, name in enumerate(imgs, 1):
    img = Image.open(f"images_output/{name}")
    plt.subplot(2, 2, i)  # 2 rows, 2 cols
    plt.imshow(img)
    plt.axis("off")
    plt.title(name)

plt.show()
